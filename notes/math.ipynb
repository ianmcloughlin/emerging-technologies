# %% [markdown]
# # Math for Quantum

# %%
# Numerical arrays and operations.
import numpy as np

# Plotting.
import matplotlib.pyplot as plt

# %% [markdown]
# ## Column Vectors

# %% [markdown]
# > Suppose $X$ is a bit. Based on what we know or expect about what has happened to in the past, we might perhaps believe that is in the classical state $0$ with probability $\frac{3}{4}$ and $1$ with probability $\frac{1}{4}$. We may represent these beliefs by... a column vector.
# >
# > $ \begin{bmatrix} 0.75 \\ 0.25 \end{bmatrix} $
# >
# > *From [Classical states and probability vectors](https://quantum.cloud.ibm.com/learning/en/courses/basics-of-quantum-information/single-systems/classical-information#classical-states-and-probability-vectors) on IBM Quantum Learning.*

# %%
# The column vector in numpy.
x = np.array([[0.75], [0.25]])

# %%
# Show.
x
# Out:
# array([[0.75],
#        [0.25]])

# %%
# Cleaner.
print(x)
# Out:
# [[0.75]
#  [0.25]]

# %% [markdown]
# > We can represent any probabilistic state through a column vector satisfying two properties:
# >
# > 1. All entries of the vector are nonnegative real numbers.
# > 2. The sum of the entries is equal to 1.
# >
# > *From [Classical states and probability vectors](https://quantum.cloud.ibm.com/learning/en/courses/basics-of-quantum-information/single-systems/classical-information#classical-states-and-probability-vectors) on IBM Quantum Learning.*

# %%
# Type - floats represent real numbers.
x.dtype
# Out:
# dtype('float64')

# %%
# All nonnegative.
np.all(x >= 0.0)
# Out:
# np.True_

# %%
# The sum of all probabilities should be 1.
x.sum()
# Out:
# np.float64(1.0)

# %% [markdown]
# ## Zero and One
#
# > For example, assuming that the system we have in mind is a bit, the standard basis vectors are given by
# >
# > $\ket{0} = \begin{bmatrix} 1 \\ 0 \end{bmatrix}, \qquad \ket{1} = \begin{bmatrix} 0 \\ 1 \end{bmatrix} $
# >
# > *From [Measuring probabilistic states
# ](https://quantum.cloud.ibm.com/learning/en/courses/basics-of-quantum-information/single-systems/classical-information#measuring-probabilistic-states) on IBM Quantum Learning.*

# %%
# Always 0.
zero = np.array([[1], [0]])

print(zero)
# Out:
# [[1]
#  [0]]

# %%
# Always 1.
one = np.array([[0],[1]])

print(one)
# Out:
# [[0]
#  [1]]

# %%
# Sometimes call these ket_0 and ket_1.
ket_0 = np.array([[1], [0]])
ket_1 = np.array([[0], [1]])

# %%
# ket_0 and ket_1 work well together to represent other states.
ket_x = 0.75 * ket_0 + 0.25 * ket_1

print(ket_x)
# Out:
# [[0.75]
#  [0.25]]

# %% [markdown]
# ## Matrices
#
# > The product C of two matrices A and B is defined as
# > $$c_{ik} = a_{ij}b_{jk},$$
# > where $j$ is summed over for all possible values of $i$ and $k$ and the notation above uses the Einstein summation convention.
# >
# > *From [Matrix Multiplication](https://mathworld.wolfram.com/MatrixMultiplication.html) on Wolfram MathWorld.*

# %% [markdown]
# <svg class="typst-doc" viewBox="0 0 418.34278915135616 279.5681102362205" width="418.34278915135616pt" height="279.5681102362205pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:h5="http://www.w3.org/1999/xhtml">
#     <path class="typst-shape" fill="#ffffff" fill-rule="nonzero" d="M 0 0v 279.5681 h 418.3428 v -279.5681 Z "/>
#     <g>
#         <g class="typst-group" transform="matrix(1 0 0 1 14.173228346456693 14.173228346456693)">
#             <g>
#                 <path class="typst-shape" fill="none" stroke="#aaaaaab2" stroke-width="4" stroke-linecap="butt" stroke-linejoin="miter" stroke-miterlimit="4" transform="matrix(1 0 0 1 19.610377952755904 11.338582677165354)" d="M 0 0h 96.37795 "/>
#                 <path class="typst-shape" fill="none" stroke="#ff4136b2" stroke-width="4" stroke-linecap="butt" stroke-linejoin="miter" stroke-miterlimit="4" transform="matrix(1 0 0 1 19.610377952755904 45.354330708661415)" d="M 0 0h 96.37795 "/>
#                 <path class="typst-shape" fill="none" stroke="#aaaaaab2" stroke-width="4" stroke-linecap="butt" stroke-linejoin="miter" stroke-miterlimit="4" transform="matrix(1 0 0 1 19.610377952755904 82.20472440944881)" d="M 0 0h 96.37795 "/>
#                 <path class="typst-shape" fill="none" stroke="#0074d9b2" stroke-width="4" stroke-linecap="butt" stroke-linejoin="miter" stroke-miterlimit="4" transform="matrix(1 0 0 1 152.83872440944882 0)" d="M 0 0v 93.543304 "/>
#                 <path class="typst-shape" fill="none" stroke="#aaaaaab2" stroke-width="4" stroke-linecap="butt" stroke-linejoin="miter" stroke-miterlimit="4" transform="matrix(1 0 0 1 189.68911811023622 0)" d="M 0 0v 93.543304 "/>
#                 <path class="typst-shape" fill="none" stroke="#aaaaaab2" stroke-width="4" stroke-linecap="butt" stroke-linejoin="miter" stroke-miterlimit="4" transform="matrix(1 0 0 1 226.53951181102363 0)" d="M 0 0v 93.543304 "/>
#                 <path class="typst-shape" fill="none" transform="matrix(1 0 0 1 0 5.792913385826793)" d="M 0 0h 141.268 v 101.8 h -141.268 v -101.8 Z "/>
#                 <g class="typst-group">
#                     <g>
#                         <g class="typst-group" transform="matrix(1 0 0 1 -0.000000012598420868217065 5.792913382677169)">
#                             <g>
#                                 <g class="typst-text" transform="matrix(1 0 0 -1 0 51.800000000000004)">
#                                     <use xlink:href="#gAC5A9219C6990A472600B6ED9534551A" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                 </g>
#                                 <g class="typst-group">
#                                     <g>
#                                         <g class="typst-text" transform="matrix(1 0 0 -1 26.68 12.912000000000004)">
#                                             <use xlink:href="#g16C7AE72E298DD8A5C078A933EB3640F" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                         </g>
#                                         <g class="typst-text" transform="matrix(1 0 0 -1 26.68 48.800000000000004)">
#                                             <use xlink:href="#g45CABA9071E8C04F7A9C102FE03FAF34" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                         </g>
#                                         <g class="typst-text" transform="matrix(1 0 0 -1 26.68 84.688)">
#                                             <use xlink:href="#gFBA1B85E73BD26C27064DA010B0E306D" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                         </g>
#                                         <g class="typst-text" transform="matrix(1 0 0 -1 62.612 12.912000000000004)">
#                                             <use xlink:href="#gC4E85ADB7EBF7C0977895A8688789731" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                         </g>
#                                         <g class="typst-text" transform="matrix(1 0 0 -1 62.612 48.800000000000004)">
#                                             <use xlink:href="#gDCFDD9EECCE5548CAAF31CE89F040F0D" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                         </g>
#                                         <g class="typst-text" transform="matrix(1 0 0 -1 62.612 84.688)">
#                                             <use xlink:href="#g40482A894A0E8A56AB625C9C4C2BF1AB" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                         </g>
#                                         <g class="typst-text" transform="matrix(1 0 0 -1 98.544 12.912000000000004)">
#                                             <use xlink:href="#g6D47F65A97623BA9A9323E44718A5CB8" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                         </g>
#                                         <g class="typst-text" transform="matrix(1 0 0 -1 98.6 48.800000000000004)">
#                                             <use xlink:href="#g66AD1E8E878BF176923D06864C9AA159" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                         </g>
#                                         <g class="typst-text" transform="matrix(1 0 0 -1 98.6 84.688)">
#                                             <use xlink:href="#g9603C2622929BFF8AF07843829861C0C" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                         </g>
#                                     </g>
#                                 </g>
#                                 <g class="typst-text" transform="matrix(1 0 0 -1 114.588 51.800000000000004)">
#                                     <use xlink:href="#g4D529506BBFB176D8D77A5EB8D4768AC" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                 </g>
#                             </g>
#                         </g>
#                     </g>
#                 </g>
#                 <path class="typst-shape" fill="none" transform="matrix(1 0 0 1 119.05511811023622 5.792913385826793)" d="M 0 0h 141.268 v 101.8 h -141.268 v -101.8 Z "/>
#                 <g class="typst-group">
#                     <g>
#                         <g class="typst-group" transform="matrix(1 0 0 1 119.0551180976378 5.792913382677169)">
#                             <g>
#                                 <g class="typst-text" transform="matrix(1 0 0 -1 0 51.800000000000004)">
#                                     <use xlink:href="#gAC5A9219C6990A472600B6ED9534551A" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                 </g>
#                                 <g class="typst-group">
#                                     <g>
#                                         <g class="typst-text" transform="matrix(1 0 0 -1 26.68 12.912000000000004)">
#                                             <use xlink:href="#g66AD1E8E878BF176923D06864C9AA159" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                         </g>
#                                         <g class="typst-text" transform="matrix(1 0 0 -1 26.68 48.800000000000004)">
#                                             <use xlink:href="#gDCFDD9EECCE5548CAAF31CE89F040F0D" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                         </g>
#                                         <g class="typst-text" transform="matrix(1 0 0 -1 26.68 84.688)">
#                                             <use xlink:href="#g9603C2622929BFF8AF07843829861C0C" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                         </g>
#                                         <g class="typst-text" transform="matrix(1 0 0 -1 62.612 12.912000000000004)">
#                                             <use xlink:href="#gFBA1B85E73BD26C27064DA010B0E306D" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                         </g>
#                                         <g class="typst-text" transform="matrix(1 0 0 -1 62.612 48.800000000000004)">
#                                             <use xlink:href="#g45CABA9071E8C04F7A9C102FE03FAF34" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                         </g>
#                                         <g class="typst-text" transform="matrix(1 0 0 -1 62.612 84.688)">
#                                             <use xlink:href="#g16C7AE72E298DD8A5C078A933EB3640F" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                         </g>
#                                         <g class="typst-text" transform="matrix(1 0 0 -1 98.6 12.912000000000004)">
#                                             <use xlink:href="#gC4E85ADB7EBF7C0977895A8688789731" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                         </g>
#                                         <g class="typst-text" transform="matrix(1 0 0 -1 98.6 48.800000000000004)">
#                                             <use xlink:href="#g40482A894A0E8A56AB625C9C4C2BF1AB" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                         </g>
#                                         <g class="typst-text" transform="matrix(1 0 0 -1 98.544 84.688)">
#                                             <use xlink:href="#g6D47F65A97623BA9A9323E44718A5CB8" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                         </g>
#                                     </g>
#                                 </g>
#                                 <g class="typst-text" transform="matrix(1 0 0 -1 114.588 51.800000000000004)">
#                                     <use xlink:href="#g4D529506BBFB176D8D77A5EB8D4768AC" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                 </g>
#                             </g>
#                         </g>
#                     </g>
#                 </g>
#                 <path class="typst-shape" fill="none" transform="matrix(1 0 0 1 32.396834645669294 170.591968503937)" d="M 0 0h 31.12 v 27.32 h -31.12 v -27.32 Z "/>
#                 <g class="typst-group">
#                     <g>
#                         <g class="typst-group" transform="matrix(1 0 0 1 32.39683463779527 170.5919685023622)">
#                             <g>
#                                 <g class="typst-text" transform="matrix(1 0 0 -1 0 27.320000000000004)">
#                                     <use xlink:href="#gD6E1E68673994A23B061225B4EF2981B" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                 </g>
#                             </g>
#                         </g>
#                     </g>
#                 </g>
#                 <path class="typst-shape" fill="none" transform="matrix(1 0 0 1 57.10414173228347 147.5251968503937)" d="M 0 0h 168.792 v 101.8 h -168.792 v -101.8 Z "/>
#                 <g class="typst-group">
#                     <g>
#                         <g class="typst-group" transform="matrix(1 0 0 1 57.10414172755905 147.5251968472441)">
#                             <g>
#                                 <g class="typst-text" transform="matrix(1 0 0 -1 0 51.800000000000004)">
#                                     <use xlink:href="#gAC5A9219C6990A472600B6ED9534551A" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                 </g>
#                                 <g class="typst-group">
#                                     <g>
#                                         <g class="typst-text" transform="matrix(1 0 0 -1 31.719999999999995 12.912000000000004)">
#                                             <use xlink:href="#gCAEC19024DED08FDFD3528BF34C6D29E" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                         </g>
#                                         <g class="typst-text" transform="matrix(1 0 0 -1 26.68 48.800000000000004)">
#                                             <use xlink:href="#g66AD1E8E878BF176923D06864C9AA159" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                         </g>
#                                         <g class="typst-text" transform="matrix(1 0 0 -1 42.612 48.800000000000004)">
#                                             <use xlink:href="#g40482A894A0E8A56AB625C9C4C2BF1AB" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                         </g>
#                                         <g class="typst-text" transform="matrix(1 0 0 -1 31.719999999999995 84.688)">
#                                             <use xlink:href="#gCAEC19024DED08FDFD3528BF34C6D29E" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                         </g>
#                                         <g class="typst-text" transform="matrix(1 0 0 -1 78.544 12.912000000000004)">
#                                             <use xlink:href="#gCAEC19024DED08FDFD3528BF34C6D29E" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                         </g>
#                                         <g class="typst-text" transform="matrix(1 0 0 -1 78.544 48.8)">
#                                             <use xlink:href="#gCAEC19024DED08FDFD3528BF34C6D29E" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                         </g>
#                                         <g class="typst-text" transform="matrix(1 0 0 -1 78.544 84.688)">
#                                             <use xlink:href="#gCAEC19024DED08FDFD3528BF34C6D29E" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                         </g>
#                                         <g class="typst-text" transform="matrix(1 0 0 -1 120.32799999999999 12.912000000000004)">
#                                             <use xlink:href="#gCAEC19024DED08FDFD3528BF34C6D29E" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                         </g>
#                                         <g class="typst-text" transform="matrix(1 0 0 -1 120.32799999999999 48.8)">
#                                             <use xlink:href="#gCAEC19024DED08FDFD3528BF34C6D29E" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                         </g>
#                                         <g class="typst-text" transform="matrix(1 0 0 -1 120.32799999999999 84.688)">
#                                             <use xlink:href="#gCAEC19024DED08FDFD3528BF34C6D29E" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                         </g>
#                                     </g>
#                                 </g>
#                                 <g class="typst-text" transform="matrix(1 0 0 -1 142.112 51.800000000000004)">
#                                     <use xlink:href="#g4D529506BBFB176D8D77A5EB8D4768AC" x="0" y="0" fill="#000000" fill-rule="nonzero"/>
#                                 </g>
#                             </g>
#                         </g>
#                     </g>
#                 </g>
#                 <path class="typst-shape" fill="#2ecc4099" fill-rule="nonzero" transform="matrix(1 0 0 1 338.50801574803154 110.55118110236221)" d="M 0 0v 48.188976 h 8.503937 v -48.188976 h -8.503937 Z "/>
#                 <path class="typst-shape" fill="#2ecc4099" fill-rule="nonzero" transform="matrix(1 0 0 1 355.51588976377957 110.55118110236221)" d="M 0 0v 48.188976 h 9.92126 v -48.188976 h -9.92126 Z "/>
#                 <path class="typst-shape" fill="#2ecc4099" fill-rule="nonzero" transform="matrix(1 0 0 1 372.52376377952754 110.55118110236221)" d="M 0 0v 48.188976 h 9.92126 v -48.188976 h -9.92126 Z "/>
.7020001 c 0 1.3300002 -0.8260002 2.366 -2.1140003 2.366 Z m -2.478 -4.508 c 0 0.3779999 0.16799998 1.218 0.5179999 2.534 c 0.042000055 0.18200016 0.1400001 0.36399984 0.32200003 0.5739999 c 0.5180001 0.60200024 1.0500002 0.8960004 1.5960002 0.8960004 c 0.6300001 0 0.95200014 -0.43400002 0.95200014 -1.2880001 c 0 -0.81200004 -0.43400002 -2.1840003 -0.7140002 -2.7440002 c -0.2800002 -0.58800006 -0.9100001 -1.316 -1.6660001 -1.316 c -0.67199993 0 -1.0079999 0.616 -1.0079999 1.3440001 Z "/>
#         </symbol>
#     </defs>
# </svg>

# %%
# Matrices as two dimensional arrays.
A = [
  [5, 8, 7],
  [9, 2, 1],
  [4, 6, 3],
]

B = [
  [1, 4, 8],
  [2, 9, 6],
  [3, 5, 7],
]

# %%
# Number of rows in A.
len(A)
# Out:
# 3

# %%
# Number of columns in B.
len(B[0])
# Out:
# 3

# %%
# Multiply.
def matrix_multiply(X, Y):
  """
  Multiply matrices X and Y. Note we should check but don't, for each matrix:
    1. Each row has same number of elements.
    2. Each column has same number of elements.
  Also that:
    3. Number of columns in X equals number of rows in Y.
  """
  return [
    [
        sum([X[i][k] * Y[k][j] for k in range(len(X))])
        for j in range(len(Y[0]))
    ]
    for i in range(len(X))
  ]

# %%
# AB.
matrix_multiply(A, B)
# Out:
# [[42, 127, 137], [16, 59, 91], [25, 85, 89]]

# %%
# Display it a bit nicer.
for r in matrix_multiply(A, B):
    print('  '.join(f'{x:3}' for x in r))
# Out:
#  42  127  137
#  16   59   91
#  25   85   89

# %% [markdown]
# ### Using NumPy
#
# > Unlike in many matrix languages, the product operator `*` operates elementwise in NumPy arrays. The matrix product can be performed using the `@` operator...
# >
# > *From [Basic operations](https://numpy.org/doc/stable/user/quickstart.html#basic-operations) in the [NumPy quickstart](https://numpy.org/doc/stable/user/quickstart.html).*

# %%
# Matrix multiplication.
np.array(A) @ np.array(B)
# Out:
# array([[ 42, 127, 137],
#        [ 16,  59,  91],
#        [ 25,  85,  89]])

# %% [markdown]
# ## Kronecker Product

# %% [markdown]
# > $$\begin{bmatrix}a_1 \\ a_2 \\ \vdots \\ a_m\end{bmatrix}\otimes\begin{bmatrix}b_1 \\ b_2 \\ \vdots \\ b_k\end{bmatrix} = \begin{bmatrix}a_1 \begin{bmatrix}b_1 \\ b_2 \\ \vdots \\ b_k\end{bmatrix} \\ a_2\begin{bmatrix}b_1 \\ b_2 \\ \vdots \\ b_k\end{bmatrix} \\ \vdots \\ a_m\begin{bmatrix}b_1 \\ b_2 \\ \vdots \\ b_k\end{bmatrix}\end{bmatrix} = \begin{bmatrix}a_1 b_1 \\ a_1 b_2 \\ \vdots \\ a_1 b_k\\ a_2b_1 \\ a_2b_2 \\ \vdots \\ a_2b_k \\ \vdots \\ a_mb_1 \\ a_mb_2 \\ \vdots \\ a_mb_k\end{bmatrix}$$
# >
# > *Adapted from [Tensor products of vectors](https://quantum.cloud.ibm.com/learning/en/courses/basics-of-quantum-information/multiple-systems/classical-information#tensor-products-of-vectors) on IBM Quantum Learning*

# %%
# Tensor product of |0> and |0>.
np.kron(ket_0, ket_0)
# Out:
# array([[1],
#        [0],
#        [0],
#        [0]])

# %%
# Tensor product of |0> and |1>.
np.kron(ket_0, ket_1)
# Out:
# array([[0],
#        [1],
#        [0],
#        [0]])

# %%
# Tensor product of |1> and |0>.
np.kron(ket_1, ket_0)
# Out:
# array([[0],
#        [0],
#        [1],
#        [0]])

# %%
# Tensor product of |1> and |1>.
np.kron(ket_1, ket_1)
# Out:
# array([[0],
#        [0],
#        [0],
#        [1]])

# %%
# ket_x and ket_0.
np.kron(ket_x, ket_0)
# Out:
# array([[0.75],
#        [0.  ],
#        [0.25],
#        [0.  ]])

# %%
# ket_x and ket_1.
np.kron(ket_x, ket_1)
# Out:
# array([[0.  ],
#        [0.75],
#        [0.  ],
#        [0.25]])

# %%
# ket_0 and ket_x.
np.kron(ket_0, ket_x)
# Out:
# array([[0.75],
#        [0.25],
#        [0.  ],
#        [0.  ]])

# %%
# ket_1 and ket_x.
np.kron(ket_1, ket_x)
# Out:
# array([[0.  ],
#        [0.  ],
#        [0.75],
#        [0.25]])

# %%
# Properties.
ket_xx = np.kron(ket_x, ket_x)

# Show.
print(ket_xx)
# Out:
# [[0.5625]
#  [0.1875]
#  [0.1875]
#  [0.0625]]

# %%
# Sum.
total = ket_xx.sum()

print(f'{total=}')
# Out:
# total=np.float64(1.0)

# %%
# All between 0 and 1 inclusive.
all_nonneg = ((0.0 <= ket_xx) & (ket_xx <= 1.0)).all()

# Show.
print(f'{all_nonneg=}')
# Out:
# all_nonneg=np.True_

# %%
# Identity matrix.
I = np.eye(3, dtype=int)

I
# Out:
# array([[1, 0, 0],
#        [0, 1, 0],
#        [0, 0, 1]])

# %%
# Identity matrix property.
A == A @ I
# Out:
# array([[ True,  True,  True],
#        [ True,  True,  True],
#        [ True,  True,  True]])

# %%
# Identity matrix property.
np.all(A == I @ A)
# Out:
# np.True_

# %% [markdown]
# ## Complex

# %%
def c(a, b):
    """Return the matrix [[a, -b], [b, a]]."""
    return np.array([[a, -b], [b, a]])

# %%
# Identity matrix.
c(1, 0)
# Out:
# array([[1, 0],
#        [0, 1]])

# %%
# Minus identity.
c(-1, 0)
# Out:
# array([[-1,  0],
#        [ 0, -1]])

# %%
# Multiply minus I by itself.
c(-1, 0) @ c(-1, 0)
# Out:
# array([[1, 0],
#        [0, 1]])

# %%
# Another matrix.
c(0, 1)
# Out:
# array([[ 0, -1],
#        [ 1,  0]])

# %%
# Same matrix multiplied by itself.
c(0, 1) @ c(0, 1)
# Out:
# array([[-1,  0],
#        [ 0, -1]])

# %%
# Equal to minus identity.
c(-1, 0) == c(0, 1) @ c(0, 1)
# Out:
# array([[ True,  True],
#        [ True,  True]])

# %%
# Minus that matrix multiplied by itself.
c(0, -1) @ c(0, -1)
# Out:
# array([[-1,  0],
#        [ 0, -1]])

# %%
# complex in Python.
1.0j
# Out:
# 1j

# %%
# complex type.
type(1.0j)
# Out:
# complex

# %%
# Mutlply by itself.
1.0j * 1.0j
# Out:
# (-1+0j)

# %%
# Multiply by itself, get -1.
-1 == 1.0j * 1.0j
# Out:
# True

# %%
# Multiply matrices.
c(3, 2) @ c(7, 4)
# Out:
# array([[ 13, -26],
#        [ 26,  13]])

# %%
# Multiply complexes - careful with brackets!
(3+2j) * (7+4j)
# Out:
# (13+26j)

# %%
# Polar form.
x = 13+26j
np.abs(x), np.angle(x)
# Out:
# (np.float64(29.068883707497267), np.float64(1.1071487177940904))

# %% [markdown]
# ## Quadratics

# %% [markdown]
# > The formula giving the roots of a quadratic equation
# > $$ax^2+bx+c=0$$
# > as
# > $$x=\frac{-b \pm \sqrt{b^2 - 4ac}}{2a}$$
# > *From [Quadratic Formula](https://mathworld.wolfram.com/QuadraticFormula.html) on Wolfram MathWorld.*

# %% [markdown]
# $$\textrm{e.g.} \quad x^2 + 4$$

# %%
# Function.
def f(x):
  return x**2 + 4

# %%
# Values.
for x_0 in range(-3, 4):
  print(f'{x_0:3} -> {f(x_0):3}')
# Out:
#  -3 ->  13
#  -2 ->   8
#  -1 ->   5
#   0 ->   4
#   1 ->   5
#   2 ->   8
#   3 ->  13

# %%
# Values.
x = np.linspace(-5, 5, 400)
y = f(x)

# Create the plot.
plt.figure(figsize=(8, 6))
plt.plot(x, y, label=r'$y = x^2 + 4$', color='green', linewidth=2)

# Grid and axes.
plt.grid(True, linestyle='--', alpha=0.7)
plt.axhline(0, color='black', linewidth=1)
plt.axvline(0, color='black', linewidth=1)

# Annotations.
plt.xlabel('x')
plt.legend();

# %%
# Formula.
def roots(a, b, c):
  """Use the Quadratic formula on polynomial ax^2 + bx + c."""
  # numpy's sqrt will only return a complex if the argument is complex.
  a = np.complex128(a)
  b = np.complex128(b)
  c = np.complex128(c)
  # Two roots.
  x_0 = (-b + np.sqrt(b**2 - 4 * a * c)) / (2 * a)
  x_1 = (-b - np.sqrt(b**2 - 4 * a * c)) / (2 * a)
  return (x_0, x_1)

# %%
# Roots.
roots(1.0, 0.0, 4.0)
# Out:
# (np.complex128(2j), np.complex128(-0-2j))

# %% [markdown]
# ## Roots of Unity
#
# [Generated using Gemini](https://gemini.google.com/share/3ab9e42b61a8)

# %% [markdown]
# > The Euler formula, sometimes also called the Euler identity :states
# > $$e^{i \theta} = \cos \theta + i \sin \theta$$
# > *From [Euler Formula](https://mathworld.wolfram.com/EulerFormula.html) on Wolfram MathWorld.*

# %%
def plot_roots_of_unity(d):
    # Calculate the angles (0 to 2*pi)
    k = np.arange(d)
    angles = 2 * np.pi * k / d
    
    # Calculate real (x) and imaginary (y) parts
    x = np.cos(angles)
    y = np.sin(angles)
    
    # Create the plot
    plt.figure(figsize=(6, 6))
    
    # Draw the unit circle for reference
    circle_theta = np.linspace(0, 2*np.pi, 200)
    plt.plot(np.cos(circle_theta), np.sin(circle_theta), color='lightgray', linestyle='--')
    
    # Plot the roots
    plt.scatter(x, y, color='red', zorder=5)
    
    # Optionally draw lines from the origin or connect the roots
    # To close the polygon, we append the first point to the end
    x_poly = np.append(x, x[0])
    y_poly = np.append(y, y[0])
    plt.plot(x_poly, y_poly, 'b-', alpha=0.5, label=f'{d}-gon')

    # Formatting the plane
    plt.axhline(0, color='black', lw=1)
    plt.axvline(0, color='black', lw=1)
    plt.title(f'{d}th Roots of Unity')
    plt.xlabel(r'$\mathbb{R}$')
    plt.ylabel(r'$i$')
    plt.axis('equal') # Keep the circle circular
    plt.grid(True, linestyle=':', alpha=0.6)
    plt.legend()
    
    plt.show()

# Example: Draw the 4th roots of unity
plot_roots_of_unity(4)

# %%
# Number of roots.
d = 4

# Angles.
angles = np.array([i * 2.0 * np.pi / d for i in range(d)])

# Print.
for theta in angles:
  print(f'{theta:.2f}: {np.exp(1.0j * theta):.2f}')
# Out:
# 0.00: 1.00+0.00j
# 1.57: 0.00+1.00j
# 3.14: -1.00+0.00j
# 4.71: -0.00-1.00j

# %% [markdown]
# ## End
